# %% [markdown]
# Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import rdflib
from rdflib import Graph, Literal, Namespace, RDF, URIRef, OWL
from rdflib.extras.external_graph_libs import rdflib_to_networkx_digraph
from rdflib.namespace import DC, FOAF

from owlready2 import *
from owlready2 import get_ontology

import networkx as nx
import networkx.algorithms.community as nx_comm

from sklearn.decomposition import PCA
import seaborn as sns
# Out:
# * Owlready2 * Warning: optimized Cython parser module 'owlready2_optimized' is not available, defaulting to slower Python implementation

# %% [markdown]
# Loading the triples

# %%
# load csv medsur.csv
colnames = ["subject", "predicate", "object"]
triples_df = pd.read_csv('medsur.csv', names=colnames, header=None)

triples_df['object'] = triples_df['object'].str.rstrip()
triples_df['subject'] = triples_df['subject'].str.rstrip() 
triples_df['predicate'] = triples_df['predicate'].str.rstrip() 

triples_df = triples_df.drop_duplicates()
triples_df = triples_df.dropna()

# filter out all triples that contain /nan
triples_df = triples_df[~triples_df['subject'].str.contains("/nan")]
triples_df = triples_df[~triples_df['object'].str.contains("/nan")]

print(triples_df.head())
# Out:
#                                subject  \
# 0  http://www.medsur.org/patient_10507
# 1  http://www.medsur.org/patient_10594
# 2   http://www.medsur.org/patient_4479
# 3  http://www.medsur.org/patient_13760
# 4   http://www.medsur.org/patient_2136
#
#                                    predicate  \
# 0   http://example.org/medsur.rdf#hasOutcome
# 1       http://example.org/medsur.rdf#hasLLT
# 2  http://example.org/medsur.rdf#hasAgeGroup
# 3      http://example.org/medsur.rdf#hasHLGT
# 4       http://example.org/medsur.rdf#hasSOC
#
#                                    object
# 0   http://www.medsur.org/outcome/Ongoing
# 1  http://www.medsur.org/symptom/10046901
# 2         http://www.medsur.org/age/25_44
# 3     http://www.medsur.org/hlgt/10018424
# 4      http://www.medsur.org/soc/10007541

# %% [markdown]
# Filter triples to get patient characteristics

# %%
# only select triples that contains the predicate 'hasGender' (gender) and 'hasAgeGroup' (age group) and 'hasWeightGroup' (weight group)

triples_df = triples_df[(triples_df['predicate'] == 'http://example.org/medsur.rdf#hasGender') | (triples_df['predicate'] == 'http://example.org/medsur.rdf#hasAgeGroup') | (triples_df['predicate'] == 'http://example.org/medsur.rdf#hasWeightGroup')]

print(triples_df.head())
# Out:
#                                 subject  \
# 2    http://www.medsur.org/patient_4479
# 7    http://www.medsur.org/patient_2752
# 11   http://www.medsur.org/patient_6891
# 12  http://www.medsur.org/patient_13753
# 15   http://www.medsur.org/patient_7150
#
#                                     predicate  \
# 2   http://example.org/medsur.rdf#hasAgeGroup
# 7   http://example.org/medsur.rdf#hasAgeGroup
# 11    http://example.org/medsur.rdf#hasGender
# 12  http://example.org/medsur.rdf#hasAgeGroup
# 15    http://example.org/medsur.rdf#hasGender
#
#                                  object
# 2       http://www.medsur.org/age/25_44
# 7       http://www.medsur.org/age/18_24
# 11  http://www.medsur.org/gender/female
# 12      http://www.medsur.org/age/45_64
# 15    http://www.medsur.org/gender/male

# %%
triples_df.predicate.unique() # looks correct
# Out:
# array(['http://example.org/medsur.rdf#hasAgeGroup',
#        'http://example.org/medsur.rdf#hasGender',
#        'http://example.org/medsur.rdf#hasWeightGroup'], dtype=object)

# %%
# create np array of triples [[row1], [row2], ...]
triples = triples_df.values
triples[0] # looks correct
# Out:
# array(['http://www.medsur.org/patient_4479',
#        'http://example.org/medsur.rdf#hasAgeGroup',
#        'http://www.medsur.org/age/25_44'], dtype=object)

# %% [markdown]
# Train-test split

# %%
from ampligraph.evaluation import train_test_split_no_unseen

t_size = int(0.1*len(triples))

X_train, X_test = train_test_split_no_unseen(triples, test_size=t_size, allow_duplication=True)

print('Train set size: ', X_train.shape)
print('Test set size: ', X_test.shape)
# Out:
# 3597
# Train set size:  (32376, 3)
# Test set size:  (3597, 3)

# %% [markdown]
# We choose ComplEx as our Knowledge Graph Embedding model:

# %%
from ampligraph.latent_features.models import ScoringBasedEmbeddingModel
    
# Initialize a ComplEx neural embedding model: the embedding size is k,
# eta specifies the number of corruptions to generate per each positive,
# scoring_type determines the scoring function of the embedding model.
model = ScoringBasedEmbeddingModel(k=150,
                                   eta=10,
                                   scoring_type='ComplEx')

# %% [markdown]
# Compile model

# %%
import tensorflow as tf

from ampligraph.latent_features.loss_functions import get as get_loss
from ampligraph.latent_features.regularizers import get as get_regularizer

# Optimizer, loss and regularizer definition
optim = tf.keras.optimizers.Adam(learning_rate=1e-3)
loss = get_loss('pairwise', {'margin': 0.5})
regularizer = get_regularizer('LP', {'p': 2, 'lambda': 1e-5})

# Compilation of the model
model.compile(loss=loss,
              optimizer='adam',
              entity_relation_regularizer=regularizer,
              entity_relation_initializer='glorot_uniform')

# %% [markdown]
# Train model

# %%
# Fit the model on training and validation set

history = model.fit(X_train,
          batch_size=64, 
          epochs=100,                    # Number of training epochs
          verbose=True                  # Enable stdout messages
          )
# Out:
# Epoch 1/100
# 507/507 [==============================] - 55s 109ms/step - loss: 309.8082
# Epoch 2/100
# 507/507 [==============================] - 50s 98ms/step - loss: 252.0926
# Epoch 3/100
# 507/507 [==============================] - 51s 100ms/step - loss: 195.2896
# Epoch 4/100
# 507/507 [==============================] - 50s 99ms/step - loss: 158.1437
# Epoch 5/100
# 507/507 [==============================] - 51s 101ms/step - loss: 134.6178
# Epoch 6/100
# 507/507 [==============================] - 51s 100ms/step - loss: 118.5915
# Epoch 7/100
# 507/507 [==============================] - 51s 101ms/step - loss: 107.0642
# Epoch 8/100
# 507/507 [==============================] - 51s 100ms/step - loss: 98.3642
# Epoch 9/100
# 507/507 [==============================] - 47s 93ms/step - loss: 91.5864
# Epoch 10/100
# 507/507 [==============================] - 46s 90ms/step - loss: 86.0976
# Epoch 11/100
# 507/507 [==============================] - 43s 84ms/step - loss: 81.5458
# Epoch 12/100
# 507/507 [==============================] - 52s 102ms/step - loss: 77.7008
# Epoch 13/100
# 507/507 [==============================] - 52s 103ms/step - loss: 74.4718
# Epoch 14/100
# 507/507 [==============================] - 49s 96ms/step - loss: 71.6331
# Epoch 15/100
# 507/507 [==============================] - 41s 82ms/step - loss: 69.1751
# Epoch 16/100
# 507/507 [==============================] - 44s 87ms/step - loss: 67.0183
# Epoch 17/100
# 507/507 [==============================] - 51s 100ms/step - loss: 65.0871
# Epoch 18/100
# 507/507 [==============================] - 49s 97ms/step - loss: 63.3642
# Epoch 19/100
# 507/507 [==============================] - 40s 80ms/step - loss: 61.7821
# 507/507 [==============================] - 43s 86ms/step - loss: 36.0754
# Epoch 97/100
# 507/507 [==============================] - 40s 80ms/step - loss: 35.9904
# Epoch 98/100
# 507/507 [==============================] - 40s 79ms/step - loss: 35.9121
# Epoch 99/100
# 507/507 [==============================] - 41s 81ms/step - loss: 35.8271
# Epoch 100/100
# 507/507 [==============================] - 42s 82ms/step - loss: 35.7506

# %% [markdown]
# An additional step when evaluating KGEs: Define a filter so that no negative statements generated by the corruption procedure are actually positives.

# %%
filter = {'test': np.concatenate([X_train, X_test])}

# %% [markdown]
# Evaluate model

# %%
ranks = model.evaluate(X_test,
                       use_filter=filter,
                       corrupt_side='s,o',
                       verbose=True)
# Out:
# 114/114 [==============================] - 75s 657ms/step

# %% [markdown]
# We used the mrr_score (mean reciprocal rank) and hits_at_n_score functions to evaluate the quality of our predictions:

# %%
from ampligraph.evaluation import mr_score, mrr_score, hits_at_n_score

mr = mr_score(ranks)
mrr = mrr_score(ranks)

print("MRR: %.2f" % (mrr))
print("MR: %.2f" % (mr))

hits_10 = hits_at_n_score(ranks, n=10)
print("Hits@10: %.2f" % (hits_10))
hits_3 = hits_at_n_score(ranks, n=3)
print("Hits@3: %.2f" % (hits_3))
hits_1 = hits_at_n_score(ranks, n=1)
print("Hits@1: %.2f" % (hits_1))
# Out:
# MRR: 0.03
# MR: 4373.72
# Hits@10: 0.09
# Hits@3: 0.03
# Hits@1: 0.01

# %% [markdown]
# Get embeddings for PTCodes

# %%
patients = triples_df.subject.unique()
embeddings = dict(zip(patients, model.get_embeddings(patients)))

# %% [markdown]
# We use PCA to project the embeddings from the 200 space into 2D space:

# %%
embeddings_2d = PCA(n_components=2).fit_transform(np.array([i for i in embeddings.values()]))

# %% [markdown]
# Find the ideal k-value

# %%
from sklearn.cluster import KMeans

WCSS = []
for i in range(1, 11):
    km = KMeans(n_clusters=i, n_init=50, max_iter=500, random_state=0,init = 'k-means++')
    km.fit(embeddings_2d )
    WCSS.append(km.inertia_)

# plot
plt.plot(range(1, 11), WCSS, marker='o')
plt.xlabel('Number of clusters')
plt.ylabel('Distortion')
plt.show() # Based on elbow method, k should be 3.

# %% [markdown]
# We now cluster the patient embeddings on its original 200-dimensional space:

# %%
from ampligraph.discovery import find_clusters

clustering_algorithm = KMeans(n_clusters=3, n_init=50, max_iter=500, random_state=0)
clusters = find_clusters(patients, model, clustering_algorithm, mode='e')

print(len(clusters))
print(len(patients))
# Out:
# 14650
# 14650

# %% [markdown]
# Store the clusters for later use

# %%
# Cluster-patient dictionary

results = dict(zip(clusters, patients))

with open("clusters_chars.txt", 'w') as f: 
    for key, value in results.items(): 
        f.write('%s:%s\n' % (key, value))

# %% [markdown]
# Visualization

# %%
plot_df = pd.DataFrame({"patients": patients, 
                        "embedding1": embeddings_2d[:, 0], 
                        "embedding2": embeddings_2d[:, 1],
                        "cluster": "cluster" + pd.Series(clusters).astype(str)})

# %%
# Plot 2D embeddings
def plot_clusters(hue):
    plt.figure(figsize=(12, 12))
    plt.title("{} embeddings".format(hue).capitalize())
    ax = sns.scatterplot(data=plot_df,
                         x="embedding1", y="embedding2", hue=hue)

# %%
plot_clusters("cluster")
